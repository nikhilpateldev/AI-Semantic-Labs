# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: requests in c:\users\nikhil\anaconda3\lib\site-packages (from -r requirements.txt (line 1)) (2.32.3)
# Collecting qdrant-client (from -r requirements.txt (line 2))
#   Downloading qdrant_client-1.15.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: python-dotenv in c:\users\nikhil\anaconda3\lib\site-packages (from -r requirements.txt (line 3)) (1.1.0)
# Collecting pdfplumber (from -r requirements.txt (line 4))
#   Downloading pdfplumber-0.11.7-py3-none-any.whl.metadata (42 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\nikhil\anaconda3\lib\site-packages (from -r requirements.txt (line 5)) (4.12.3)
# Requirement already satisfied: tqdm in c:\users\nikhil\anaconda3\lib\site-packages (from -r requirements.txt (line 6)) (4.67.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nikhil\anaconda3\lib\site-packages (from requests->-r requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nikhil\anaconda3\lib\site-packages (from requests->-r requirements.txt (line 1)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nikhil\anaconda3\lib\site-packages (from requests->-r requirements.txt (line 1)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nikhil\anaconda3\lib\site-packages (from requests->-r requirements.txt (line 1)) (2025.4.26)
# Collecting grpcio>=1.41.0 (from qdrant-client->-r requirements.txt (line 2))
#   Downloading grpcio-1.76.0-cp313-cp313-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: httpx>=0.20.0 in c:\users\nikhil\anaconda3\lib\site-packages (from httpx[http2]>=0.20.0->qdrant-client->-r requirements.txt (line 2)) (0.28.1)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\nikhil\anaconda3\lib\site-packages (from qdrant-client->-r requirements.txt (line 2)) (2.1.3)
# Collecting portalocker<4.0,>=2.7.0 (from qdrant-client->-r requirements.txt (line 2))
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: protobuf>=3.20.0 in c:\users\nikhil\anaconda3\lib\site-packages (from qdrant-client->-r requirements.txt (line 2)) (5.29.3)
# Requirement already satisfied: pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8 in c:\users\nikhil\anaconda3\lib\site-packages (from qdrant-client->-r requirements.txt (line 2)) (2.10.3)
# Requirement already satisfied: pywin32>=226 in c:\users\nikhil\anaconda3\lib\site-packages (from portalocker<4.0,>=2.7.0->qdrant-client->-r requirements.txt (line 2)) (308)
# Collecting pdfminer.six==20250506 (from pdfplumber->-r requirements.txt (line 4))
#   Downloading pdfminer_six-20250506-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: Pillow>=9.1 in c:\users\nikhil\anaconda3\lib\site-packages (from pdfplumber->-r requirements.txt (line 4)) (11.1.0)
# Collecting pypdfium2>=4.18.0 (from pdfplumber->-r requirements.txt (line 4))
#   Downloading pypdfium2-5.0.0-py3-none-win_amd64.whl.metadata (67 kB)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\nikhil\anaconda3\lib\site-packages (from pdfminer.six==20250506->pdfplumber->-r requirements.txt (line 4)) (44.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\nikhil\anaconda3\lib\site-packages (from beautifulsoup4->-r requirements.txt (line 5)) (2.5)
# Requirement already satisfied: colorama in c:\users\nikhil\anaconda3\lib\site-packages (from tqdm->-r requirements.txt (line 6)) (0.4.6)
# Requirement already satisfied: cffi>=1.12 in c:\users\nikhil\anaconda3\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber->-r requirements.txt (line 4)) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\nikhil\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber->-r requirements.txt (line 4)) (2.21)
# Requirement already satisfied: typing-extensions~=4.12 in c:\users\nikhil\anaconda3\lib\site-packages (from grpcio>=1.41.0->qdrant-client->-r requirements.txt (line 2)) (4.12.2)
# Requirement already satisfied: anyio in c:\users\nikhil\anaconda3\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client->-r requirements.txt (line 2)) (4.7.0)
# Requirement already satisfied: httpcore==1.* in c:\users\nikhil\anaconda3\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client->-r requirements.txt (line 2)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\nikhil\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client->-r requirements.txt (line 2)) (0.16.0)
# Collecting h2<5,>=3 (from httpx[http2]>=0.20.0->qdrant-client->-r requirements.txt (line 2))
#   Downloading h2-4.3.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client->-r requirements.txt (line 2))
#   Downloading hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client->-r requirements.txt (line 2))
#   Downloading hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\nikhil\anaconda3\lib\site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant-client->-r requirements.txt (line 2)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\nikhil\anaconda3\lib\site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant-client->-r requirements.txt (line 2)) (2.27.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\nikhil\anaconda3\lib\site-packages (from anyio->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client->-r requirements.txt (line 2)) (1.3.0)
# Downloading qdrant_client-1.15.1-py3-none-any.whl (337 kB)
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Downloading pdfplumber-0.11.7-py3-none-any.whl (60 kB)
# Downloading pdfminer_six-20250506-py3-none-any.whl (5.6 MB)
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ------- -------------------------------- 1.0/5.6 MB 5.5 MB/s eta 0:00:01
#    ------------- -------------------------- 1.8/5.6 MB 4.5 MB/s eta 0:00:01
#    ------------------ --------------------- 2.6/5.6 MB 4.3 MB/s eta 0:00:01
#    -------------------------- ------------- 3.7/5.6 MB 4.2 MB/s eta 0:00:01
#    ------------------------------- -------- 4.5/5.6 MB 4.1 MB/s eta 0:00:01
#    ------------------------------------- -- 5.2/5.6 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 5.6/5.6 MB 4.0 MB/s eta 0:00:00
# Downloading grpcio-1.76.0-cp313-cp313-win_amd64.whl (4.7 MB)
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.8/4.7 MB 4.0 MB/s eta 0:00:01
#    ------------- -------------------------- 1.6/4.7 MB 4.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 2.6/4.7 MB 3.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 3.4/4.7 MB 3.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 4.2/4.7 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 4.7/4.7 MB 3.8 MB/s eta 0:00:00
# Downloading h2-4.3.0-py3-none-any.whl (61 kB)
# Downloading hpack-4.1.0-py3-none-any.whl (34 kB)
# Downloading hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Downloading pypdfium2-5.0.0-py3-none-win_amd64.whl (3.1 MB)
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ------------- -------------------------- 1.0/3.1 MB 5.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.8/3.1 MB 4.5 MB/s eta 0:00:01
#    --------------------------------- ------ 2.6/3.1 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 3.1/3.1 MB 4.2 MB/s eta 0:00:00
# Installing collected packages: pypdfium2, portalocker, hyperframe, hpack, grpcio, h2, pdfminer.six, qdrant-client, pdfplumber
#
#    ---------------------------------------- 0/9 [pypdfium2]
#    ------------- -------------------------- 3/9 [hpack]
#    ----------------- ---------------------- 4/9 [grpcio]
#    ---------------------- ----------------- 5/9 [h2]
#    -------------------------- ------------- 6/9 [pdfminer.six]
#    -------------------------- ------------- 6/9 [pdfminer.six]
#    ------------------------------- -------- 7/9 [qdrant-client]
#    ------------------------------- -------- 7/9 [qdrant-client]
#    ------------------------------- -------- 7/9 [qdrant-client]
#    ------------------------------- -------- 7/9 [qdrant-client]
#    ----------------------------------- ---- 8/9 [pdfplumber]
#    ---------------------------------------- 9/9 [pdfplumber]
#
# Successfully installed grpcio-1.76.0 h2-4.3.0 hpack-4.1.0 hyperframe-6.1.0 pdfminer.six-20250506 pdfplumber-0.11.7 portalocker-3.2.0 pypdfium2-5.0.0 qdrant-client-1.15.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python ingest.py --data-dir test_data
# Out:
# Loaded 4 documents from test_data
# Total chunks: 6
# Upserted batch 1 (6 points)
# c:\Users\Nikhil\Downloads\semantic-search-repo-with-demo-v2\python\ingest.py:50: DeprecationWarning: `recreate_collection` method is deprecated and will be removed in the future. Use `collection_exists` to check collection existence and `create_collection` instead.
#   client.recreate_collection(

# %% [markdown]
# from query import semantic_search
# results = semantic_search("how to configure IIS on Windows")
# for r in results:
#     print(r['payload']['filename'], ":", r['payload']['text'][:150])

# %%
# !dir c:\Users\Nikhil\Downloads\semantic-search-repo-with-demo-v2\python
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 2658-C19A
#
#  Directory of c:\Users\Nikhil\Downloads\semantic-search-repo-with-demo-v2\python
#
# 08-11-2025  22:12    <DIR>          .
# 08-11-2025  22:08    <DIR>          ..
# 08-11-2025  22:08               176 .env.example
# 08-11-2025  22:08    <DIR>          data
# 08-11-2025  22:08             2'220 data_loader.py
# 08-11-2025  22:08             1'356 demo.ipynb
# 09-11-2025  12:09            42'807 demo1.ipynb
# 08-11-2025  22:25             4'292 ingest.py
# 09-11-2025  12:36             2'300 query.py
# 08-11-2025  22:08                67 requirements.txt
# 08-11-2025  22:08             1'422 rerank.py
# 08-11-2025  22:08    <DIR>          test_data
# 09-11-2025  12:36    <DIR>          __pycache__
#                8 File(s)         54'640 bytes
#                5 Dir(s)  63'238'029'312 bytes free

# %%
from query import semantic_search

results = semantic_search("how to setup iss",5,True)

for r in results:
    print(r.payload['filename'], ":", r.payload['text'][:150])
# Out:
# 🔍 Raw scores:
# iis_setup.pdf → 0.6252
# iis_setup.pdf → 0.5958
# iis_setup.pdf → 0.5527
# web_servers.html → 0.4222
# devops_basics.txt → 0.3822
# cloud_intro.txt → 0.3802
# ✅ Returning 3 results (threshold=0.500)
# iis_setup.pdf : nfiguration Steps:
# 1. After installation, open IIS Manager from the Start menu.
# 2. In the left Connections pane, expand your server node and click 'Si
# iis_setup.pdf : IIS Setup Guide - Page 1
# Introduction to IIS:
# Internet Information Services (IIS) is a flexible, secure, and manageable Web server for hosting anythin
# iis_setup.pdf : tup Guide - Page 3
# Enabling HTTPS:
# 1. Obtain an SSL certificate (self-signed or from a trusted CA).
# 2. In IIS Manager, click your site and then 'Bindi
